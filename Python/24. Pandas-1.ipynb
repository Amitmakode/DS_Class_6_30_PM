# %%
# !pip install pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = [10, 20, 30, 40, 50]
series = pd.Series(data, index=['a', 'b', 'c', 'd', 'e'])

# %%
series
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Tokyo', 'Paris'],
    'Salary': [70000, 80000, 90000, 75000]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   70000
# 1      Bob   30    London   80000
# 2  Charlie   35     Tokyo   90000
# 3    Diana   28     Paris   75000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_json("F:/Dataset/Order.json")
# Out:
#                                                 orders
# 0    {'orderID': 10248, 'customerID': 'VINET', 'emp...
# 1    {'orderID': 10249, 'customerID': 'TOMSP', 'emp...
# 2    {'orderID': 10250, 'customerID': 'HANAR', 'emp...
# 3    {'orderID': 10251, 'customerID': 'VICTE', 'emp...
# 4    {'orderID': 10252, 'customerID': 'SUPRD', 'emp...
# ..                                                 ...
# 825  {'orderID': 11073, 'customerID': 'PERIC', 'emp...
# 826  {'orderID': 11074, 'customerID': 'SIMOB', 'emp...
# 827  {'orderID': 11075, 'customerID': 'RICSU', 'emp...
# 828  {'orderID': 11076, 'customerID': 'BONAP', 'emp...
# 829  {'orderID': 11077, 'customerID': 'RATTC', 'emp...
#
# [830 rows x 1 columns]

# %%
df_csv_custom = pd.read_csv('data.csv', 
                           sep=';',           # Custom separator
                           header=0,          # Row to use as column names
                           index_col=0,       # Column to use as index
                           na_values=['N/A', 'null'],  # Additional NA values
                           dtype={'Age': int}, # Specify data types
                           nrows=1000)        # Read only first 1000 rows

# %%
df.to_json("data.json")

# %%
np.random.seed(42)
df = pd.DataFrame({
    'A': np.random.randn(100),
    'B': np.random.randint(1, 10, 100),
    'C': np.random.choice(['X', 'Y', 'Z'], 100),
    'D': pd.date_range('2023-01-01', periods=100, freq='D'),
    'E': np.random.randn(100) * 100
})

# %%
df
# Out:
#            A  B  C          D           E
# 0   0.496714  9  Y 2023-01-01   23.229616
# 1  -0.138264  5  Y 2023-01-02   17.618092
# 2   0.647689  1  Y 2023-01-03 -115.256537
# 3   1.523030  3  Y 2023-01-04 -150.076839
# 4  -0.234153  8  Z 2023-01-05   16.502280
# ..       ... .. ..        ...         ...
# 95 -1.463515  3  Z 2023-04-06   94.914299
# 96  0.296120  9  X 2023-04-07  -23.922480
# 97  0.261055  3  X 2023-04-08   85.397471
# 98  0.005113  9  X 2023-04-09  -27.104046
# 99 -0.234587  2  Y 2023-04-10  -61.309468
#
# [100 rows x 5 columns]

# %%
df.head(10)
# Out:
#           A  B  C          D           E
# 0  0.496714  9  Y 2023-01-01   23.229616
# 1 -0.138264  5  Y 2023-01-02   17.618092
# 2  0.647689  1  Y 2023-01-03 -115.256537
# 3  1.523030  3  Y 2023-01-04 -150.076839
# 4 -0.234153  8  Z 2023-01-05   16.502280
# 5 -0.234137  6  X 2023-01-06  -85.592892
# 6  1.579213  8  X 2023-01-07   -3.963614
# 7  0.767435  9  X 2023-01-08  -53.466274
# 8 -0.469474  4  X 2023-01-09 -178.849650
# 9  0.542560  1  Y 2023-01-10   35.730454

# %%
df.tail()
# Out:
#            A  B  C          D          E
# 95 -1.463515  3  Z 2023-04-06  94.914299
# 96  0.296120  9  X 2023-04-07 -23.922480
# 97  0.261055  3  X 2023-04-08  85.397471
# 98  0.005113  9  X 2023-04-09 -27.104046
# 99 -0.234587  2  Y 2023-04-10 -61.309468

# %%
df.sample(5)
# Out:
#            A  B  C          D           E
# 34  0.822545  7  X 2023-02-04   94.538169
# 29 -0.291694  2  Y 2023-01-30  166.130173
# 95 -1.463515  3  Z 2023-04-06   94.914299
# 64  0.812526  9  Y 2023-03-06  -61.513368
# 6   1.579213  8  X 2023-01-07   -3.963614

# %%
df.dtypes
# Out:
# A           float64
# B             int32
# C            object
# D    datetime64[ns]
# E           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       100 non-null    float64
#  1   B       100 non-null    int32
#  2   C       100 non-null    object
#  3   D       100 non-null    datetime64[ns]
#  4   E       100 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int32(1), object(1)
# memory usage: 3.6+ KB

# %%
df.shape
# Out:
# (100, 5)

# %%
type(df.A)
# Out:
# pandas.core.series.Series

# %%
df["A"]
# Out:
# 0     0.496714
# 1    -0.138264
# 2     0.647689
# 3     1.523030
# 4    -0.234153
#         ...
# 95   -1.463515
# 96    0.296120
# 97    0.261055
# 98    0.005113
# 99   -0.234587
# Name: A, Length: 100, dtype: float64

# %%
type(df[["A", "B"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["A", "B", "C"]]
# Out:
#            A  B  C
# 0   0.496714  9  Y
# 1  -0.138264  5  Y
# 2   0.647689  1  Y
# 3   1.523030  3  Y
# 4  -0.234153  8  Z
# ..       ... .. ..
# 95 -1.463515  3  Z
# 96  0.296120  9  X
# 97  0.261055  3  X
# 98  0.005113  9  X
# 99 -0.234587  2  Y
#
# [100 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.describe(include= "all")
# Out:
#                  A           B    C                    D           E
# count   100.000000  100.000000  100                  100  100.000000
# unique         NaN         NaN    3                  NaN         NaN
# top            NaN         NaN    X                  NaN         NaN
# freq           NaN         NaN   36                  NaN         NaN
# mean     -0.103847    4.730000  NaN  2023-02-19 12:00:00    8.073564
# min      -2.619745    1.000000  NaN  2023-01-01 00:00:00 -199.496157
# 25%      -0.600906    2.000000  NaN  2023-01-25 18:00:00  -61.360443
# 50%      -0.126956    4.000000  NaN  2023-02-19 12:00:00    3.682609
# 75%       0.405952    7.000000  NaN  2023-03-16 06:00:00   85.966970
# max       1.852278    9.000000  NaN  2023-04-10 00:00:00  238.903596
# std       0.908168    2.733463  NaN                  NaN  101.447471

# %%
df.describe().T
# Out:
#    count                 mean                  min                  25%  \
# A  100.0            -0.103847            -2.619745            -0.600906
# B  100.0                 4.73                  1.0                  2.0
# D    100  2023-02-19 12:00:00  2023-01-01 00:00:00  2023-01-25 18:00:00
# E  100.0             8.073564          -199.496157           -61.360443
#
#                    50%                  75%                  max         std
# A            -0.126956             0.405952             1.852278    0.908168
# B                  4.0                  7.0                  9.0    2.733463
# D  2023-02-19 12:00:00  2023-03-16 06:00:00  2023-04-10 00:00:00         NaN
# E             3.682609             85.96697           238.903596  101.447471

# %%
df.T
# Out:
#                     0                    1                    2   \
# A             0.496714            -0.138264             0.647689
# B                    9                    5                    1
# C                    Y                    Y                    Y
# D  2023-01-01 00:00:00  2023-01-02 00:00:00  2023-01-03 00:00:00
# E            23.229616            17.618092          -115.256537
#
#                     3                    4                    5   \
# A              1.52303            -0.234153            -0.234137
# B                    3                    8                    6
# C                    Y                    Z                    X
# D  2023-01-04 00:00:00  2023-01-05 00:00:00  2023-01-06 00:00:00
# E          -150.076839             16.50228           -85.592892
#
#                     6                    7                    8   \
# A             1.579213             0.767435            -0.469474
# ...

# %%
print(df['A'].mean())       # Mean
print(df['A'].median())     # Median
print(df['A'].mode())       # Mode
print(df['A'].std())        # Standard deviation
print(df['A'].var())        # Variance
print(df['A'].min())        # Minimum
print(df['A'].max())        # Maximum
print(df['A'].quantile(0.25))  # 25th percentile
# Out:
# -0.10384651739409384
# -0.1269562917797126
# 0    -2.619745
# 1    -1.987569
# 2    -1.959670
# 3    -1.913280
# 4    -1.763040
#         ...
# 95    1.523030
# 96    1.538037
# 97    1.564644
# 98    1.579213
# 99    1.852278
# Name: A, Length: 100, dtype: float64
# 0.9081684280078008
# 0.8247698936301602
# -2.6197451040897444
# 1.8522781845089378
# -0.6009056704964529

# %%
df.dtypes
# Out:
# A           float64
# B             int32
# C            object
# D    datetime64[ns]
# E           float64
# dtype: object

# %%
df[["A", "B", "E"]].mean()
# Out:
# A   -0.103847
# B    4.730000
# E    8.073564
# dtype: float64

# %%
df["A"].quantile(0.3)
# Out:
# -0.5067109959912698

# %%
# Count statistics
print(df['C'].value_counts())    # Count of unique values
# Out:
# C
# X    36
# Y    35
# Z    29
# Name: count, dtype: int64

# %%
print(df['C'].nunique())         # Number of unique values
# Out:
# 3

# %%
df.isnull().sum()    # Count of missing values
# Out:
# A    0
# B    0
# C    0
# D    0
# E    0
# dtype: int64

# %%
print(df.notnull().sum())
# Out:
# A    100
# B    100
# C    100
# D    100
# E    100
# dtype: int64

# %%
df.isna().sum()
# Out:
# A    0
# B    0
# C    0
# D    0
# E    0
# dtype: int64

# %%
df.head(10)
# Out:
#           A  B  C          D           E
# 0  0.496714  9  Y 2023-01-01   23.229616
# 1 -0.138264  5  Y 2023-01-02   17.618092
# 2  0.647689  1  Y 2023-01-03 -115.256537
# 3  1.523030  3  Y 2023-01-04 -150.076839
# 4 -0.234153  8  Z 2023-01-05   16.502280
# 5 -0.234137  6  X 2023-01-06  -85.592892
# 6  1.579213  8  X 2023-01-07   -3.963614
# 7  0.767435  9  X 2023-01-08  -53.466274
# 8 -0.469474  4  X 2023-01-09 -178.849650
# 9  0.542560  1  Y 2023-01-10   35.730454

# %%
df.loc[0:100:5,["A","B", "E"]]
# Out:
#            A  B           E
# 0   0.496714  9   23.229616
# 5  -0.234137  6  -85.592892
# 10 -0.463418  1  -41.453181
# 15 -0.562288  1   12.855100
# 20  1.465649  1  136.343549
# 25  0.110923  5  -62.856975
# 30 -0.601707  5  -33.424709
# 35 -1.220844  8  126.640686
# 40  0.738467  4  -73.074140
# 45 -0.719844  9  -93.259166
# 50  0.324084  3  154.306765
# 55  0.931280  4  234.799693
# 60 -0.479174  2   64.716270
# 65  1.356240  2  211.131764
# 70  0.361396  4  -48.643277
# 75  0.821903  5  -35.548864
# 80 -0.219672  3  -62.970086
# 85 -0.501757  8 -122.057010
# 90  0.097078  8  -40.791535
# 95 -1.463515  3   94.914299

# %%
df.iloc[10:50:7,0:5:2]
# Out:
#            A  C           E
# 10 -0.463418  X  -41.453181
# 17  0.314247  Y -127.087181
# 24 -0.544383  X  104.801974
# 31  1.852278  Y  -31.784691
# 38 -1.328186  Z -132.683177
# 45 -0.719844  Y  -93.259166

# %%
df1 = pd.read_csv("C:\\Users\\amitm\\Downloads\\saless.csv")

# %%
df1.shape
# Out:
# (1555, 22)

# %%
df1.head()
# Out:
#         order_id new_order_date order_date  ship_date       ship_mode  \
# 0  IN-2011-29872     2011-01-11  1/11/2011  1/15/2011  Standard Class
# 1  IN-2011-10552     2011-01-24  1/24/2011  1/30/2011  Standard Class
# 2  IN-2011-31496     2011-01-26  1/26/2011  1/28/2011    Second Class
# 3  IN-2011-76198     2011-01-26  1/26/2011   2/1/2011  Standard Class
# 4  IN-2011-60917     2011-02-11  2/11/2011  2/15/2011  Standard Class
#
#       customer_name      segment              state country market  ...  \
# 0  Dianna Vittorini     Consumer  Jammu and Kashmir   India   APAC  ...
# 1       Chuck Clark  Home Office     Madhya Pradesh   India   APAC  ...
# 2      Nathan Mautz  Home Office          Telangana   India   APAC  ...
# 3     Anna Andreadi     Consumer          Telangana   India   APAC  ...
# 4          Sung Pak    Corporate          Karnataka   India   APAC  ...
#
#           category sub_category                    product_name sales  \
# ...

# %%
df1.columns
# Out:
# Index(['order_id', 'new_order_date', 'order_date', 'ship_date', 'ship_mode',
#        'customer_name', 'segment', 'state', 'country', 'market', 'region',
#        'product_id', 'category', 'sub_category', 'product_name', 'sales',
#        'quantity', 'discount', 'profit', 'shipping_cost', 'order_priority',
#        'year'],
#       dtype='object')

# %%
df1.loc[:1500:50]
# Out:
#            order_id new_order_date  order_date   ship_date       ship_mode  \
# 0     IN-2011-29872     2011-01-11   1/11/2011   1/15/2011  Standard Class
# 50    IN-2011-43599     2011-06-02    6/2/2011    6/7/2011  Standard Class
# 100   IN-2011-75526     2011-08-22   8/22/2011   8/28/2011  Standard Class
# 150   IN-2011-68904     2011-09-26   9/26/2011   9/30/2011  Standard Class
# 200   IN-2011-23530     2011-11-09   11/9/2011  11/11/2011     First Class
# 250   IN-2011-51964     2011-12-28  12/28/2011  12/29/2011     First Class
# 300   IN-2012-17986     2012-03-19   3/19/2012   3/21/2012    Second Class
# 350   IN-2012-48240     2012-05-25   5/25/2012   5/28/2012    Second Class
# 400   IN-2012-42045     2012-06-27   6/27/2012    7/2/2012  Standard Class
# 450   ID-2012-65236     2012-08-28   8/28/2012    9/2/2012  Standard Class
# 500   IN-2012-45909     2012-10-05   10/5/2012   10/9/2012  Standard Class
# ...

# %%
df1.loc[:1500:50,["order_id","discount","segment"]].head()
# Out:
#           order_id  discount    segment
# 0    IN-2011-29872       3.0   Consumer
# 50   IN-2011-43599       3.0  Corporate
# 100  IN-2011-75526     928.0  Corporate
# 150  IN-2011-68904       4.0  Corporate
# 200  IN-2011-23530       2.0  Corporate

# %%
df1.iloc[::100,0:22:4]
# Out:
#            order_id       ship_mode country         category  quantity  \
# 0     IN-2011-29872  Standard Class   India        Furniture       142
# 100   IN-2011-75526  Standard Class   India       Technology         0
# 200   IN-2011-23530     First Class   India       Technology       276
# 300   IN-2012-17986    Second Class   India  Office Supplies        61
# 400   IN-2012-42045  Standard Class   India  Office Supplies        44
# 500   IN-2012-45909  Standard Class   India       Technology         0
# 600   IN-2012-61918  Standard Class   India  Office Supplies        18
# 700   IN-2013-29683  Standard Class   India        Furniture       613
# 800   IN-2013-60049  Standard Class   India  Office Supplies        46
# 900   IN-2013-49857    Second Class   India       Technology       776
# 1000  IN-2014-71102  Standard Class   India  Office Supplies       149
# 1100  IN-2014-42402        Same Day   India        Furniture       113
# ...

# %%
df1.describe(include="all").T
# Out:
#                  count unique                        top  freq        mean  \
# order_id          1555    785              IN-2013-78809    11         NaN
# new_order_date    1555    553                 2014-10-17    16         NaN
# order_date        1555    553                 10/17/2014    16         NaN
# ship_date         1555    572                 11/22/2014    12         NaN
# ship_mode         1555      4             Standard Class   973         NaN
# customer_name     1555    494              Arthur Gainer    17         NaN
# segment           1555      3                   Consumer   816         NaN
# state             1555     25                Maharashtra   290         NaN
# country           1555      1                      India  1555         NaN
# market            1555      1                       APAC  1555         NaN
# region            1555      1               Central Asia  1555         NaN
# ...

# %%
df2 = pd.read_csv("F:\\Dataset\\Car_prices.csv")

# %%
df2.shape
# Out:
# (558837, 16)

# %%
df
# Out:
#            A  B  C          D           E
# 0   0.496714  9  Y 2023-01-01   23.229616
# 1  -0.138264  5  Y 2023-01-02   17.618092
# 2   0.647689  1  Y 2023-01-03 -115.256537
# 3   1.523030  3  Y 2023-01-04 -150.076839
# 4  -0.234153  8  Z 2023-01-05   16.502280
# ..       ... .. ..        ...         ...
# 95 -1.463515  3  Z 2023-04-06   94.914299
# 96  0.296120  9  X 2023-04-07  -23.922480
# 97  0.261055  3  X 2023-04-08   85.397471
# 98  0.005113  9  X 2023-04-09  -27.104046
# 99 -0.234587  2  Y 2023-04-10  -61.309468
#
# [100 rows x 5 columns]

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana','Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28, 18, 23, 40, 35],
    'City': ['New York', 'London', 'Tokyo', 'Paris','New York', 'London', 'Tokyo', 'Paris'],
    'Salary': [70000, 80000, 90000, 75000, 30000, 40000, 90000, 15000]
}

# %%
df = pd.DataFrame(data)

# %%
data = df.copy()

# %%
df[df['Age'] > 30]
# Out:
#       Name  Age   City  Salary
# 2  Charlie   35  Tokyo   90000
# 6  Charlie   40  Tokyo   90000
# 7    Diana   35  Paris   15000

# %%
df[(df['Age'] > 25) & (df['City'] == 'Paris')]
# Out:
#     Name  Age   City  Salary
# 3  Diana   28  Paris   75000
# 7  Diana   35  Paris   15000

# %%
# Using isin() method
city = ['Paris', 'Tokoyo']
df[df['City'].isin(["London"])]
# Out:
#   Name  Age    City  Salary
# 1  Bob   30  London   80000
# 5  Bob   23  London   40000

# %%
# String operations in boolean indexing
print(df[df['Name'].str.contains('A')])    # Names containing 'A'
# Out:
#     Name  Age      City  Salary
# 0  Alice   25  New York   70000
# 4  Alice   18  New York   30000

# %%
print(df[df['Name'].str.startswith('B')])  # Names starting with 'A'
# Out:
#   Name  Age    City  Salary
# 1  Bob   30  London   80000
# 5  Bob   23  London   40000

# %%
df1["state"].unique()
# Out:
# array(['Jammu and Kashmir', 'Madhya Pradesh', 'Telangana', 'Karnataka',
#        'Uttar Pradesh', 'Rajasthan', 'Maharashtra', 'Andhra Pradesh',
#        'West Bengal', 'Tamil Nadu', 'Punjab', 'Gujarat', 'Delhi',
#        'Kerala', 'Bihar', 'Jharkhand', 'Uttarakhand', 'Odisha', 'Haryana',
#        'Chhattisgarh', 'Assam', 'Puducherry', 'Chandigarh', 'Manipur',
#        'Tripura'], dtype=object)
