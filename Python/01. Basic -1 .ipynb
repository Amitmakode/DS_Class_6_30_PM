# %%
print("hello python")

len("python")

# %%
datatypes 
logical function
user function
oops
library

# %%
## Data Types

# %%
int           = any whole number (0-9)
float         = any decimal number (0.5, 1.99. 3.25)
str           = any printed values/ syntax "hello", '3423', "7#py", "    "
complex       = any number with combination of real and imagine number (2x+4y = 30),  45+5j
Bool          = True / False
List          = ["py", 56, 55.77, 33+77j, True,{"jan" :31, "feb" :28, "march":31}]
tuple         = ("py", 56, 55.77, 33+77j, True)
set           = {"py", 56, 55.77, 33+77j, True}
dict          = {"jan" :31, "feb" :28, "march":31}   # key value pair

# %% [markdown]
# ## Arithmatic Operators

# %%
+ = add
- = sub
* = multi
/ = devision
% = mode
** = power
// = floor division

# %%
a = 25
b = 10

# %%
5%2
# Out:
# 1

# %%
b
# Out:
# 10

# %%
a+b
# Out:
# 35

# %%
a-b
# Out:
# 15

# %%
a/b
# Out:
# 2.5

# %%
a*b
# Out:
# 250

# %%
a%b
# Out:
# 5

# %%
b%a
# Out:
# 10

# %%
11%2
# Out:
# 1

# %%
a+b/(a/b) - a**3
# Out:
# -15596.0

# %%
a**3
# Out:
# 15625

# %%
4**2
# Out:
# 16

# %%
4**3
# Out:
# 64

# %%
4**4
# Out:
# 256

# %%
x = 100
y = 20

# %%
x*y
# Out:
# 2000

# %%
x/y
# Out:
# 5.0

# %%
x-y
# Out:
# 80

# %%
55%3
# Out:
# 1

# %%
x%y
# Out:
# 0

# %%
100%7
# Out:
# 2

# %% [markdown]
# ## Comparision Operators

# %%
==
>
<
>=
<=
!=

# %%
a
# Out:
# 25

# %%
b
# Out:
# 10

# %%
x
# Out:
# 100

# %%
y
# Out:
# 20

# %%
a==b
# Out:
# False

# %%
x > a
# Out:
# True

# %%
y > a
# Out:
# False

# %%
y == a
# Out:
# False

# %%
b < y
# Out:
# True

# %%
100 != 100
# Out:
# False

# %% [markdown]
# ## Logical Operators

# %%
and
or
in
not in
is 
is not

# %%
True and False = F
True and True  = T
False and True = F
False and False = F

# %%
True or True  = T
True or False = T
False or True = T
False or False = F

# %%
lis = [1,2,3,4,5,6,]

# %%
lis
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
20 in lis
# Out:
# False

# %%
21 in lis
# Out:
# False

# %%
a
# Out:
# 25

# %%
20 is a
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\amitm\AppData\Local\Temp\ipykernel_6228\1837879855.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   20 is a
# False

# %%
x is not 100
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\amitm\AppData\Local\Temp\ipykernel_18176\3620244120.py:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   x is not 100
# False

# %%
var = "I am a mentor"

# %%
print(var)
# Out:
# I am a mentor

# %%
print(x, y, a*b)
# Out:
# 100 20 200

# %%
print(input("tell your name "))
# Out:
# tell your name  amit
# amit

# %%
var
# Out:
# 'I am a mentor'

# %%
len(var)
# Out:
# 13

# %%
type(var)
# Out:
# str

# %%
type(x)
# Out:
# int

# %%
22//2
# Out:
# 11

# %%
20/2
# Out:
# 10.0

# %% [markdown]
# ### Bitwise operators

# %%
+=
-=
*=
/=
%=
//=
**=
